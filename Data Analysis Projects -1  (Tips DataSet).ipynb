# %%
#Importing Libraries
import pandas as pd
import seaborn as sns

# %%
#Loading dataset
df = sns.load_dataset('tips')

# %%
#Viewing few rows of dataset
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Checking for null values (if any)
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
#Checking for unique values and their frequencies for columns 'day' , 'time'
df['day'].unique()
df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df['time'].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
#Analyzing total spending including tips value and total_bill
df['total_spending'] = df['total_bill'] +df ['tip']
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  total_spending
# 0       16.99  1.01  Female     No  Sun  Dinner     2           18.00
# 1       10.34  1.66    Male     No  Sun  Dinner     3           12.00
# 2       21.01  3.50    Male     No  Sun  Dinner     3           24.51
# 3       23.68  3.31    Male     No  Sun  Dinner     2           26.99
# 4       24.59  3.61  Female     No  Sun  Dinner     4           28.20

# %%
#Visualizing proportion of Lunch and Dinner
sns.barplot(x =df.time.unique(), y=df.time.value_counts())
# Out:
# <AxesSubplot:ylabel='time'>

# %%
df.groupby(['sex'])['total_spending'].mean()
# Out:
# sex
# Male      23.833694
# Female    20.890345
# Name: total_spending, dtype: float64

# %%
df.groupby(['sex'])['total_spending'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
df.groupby(['sex'])['tip'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
df.groupby(['time'])['total_spending'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='time'>

# %%
df.groupby(['time'])['tip'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='time'>

# %%
sns.barplot(x='time',y='total_bill',hue='sex' ,data=df)
# Out:
# <AxesSubplot:xlabel='time', ylabel='total_bill'>

# %%
sns.barplot(x='time',y='tip',hue='sex' ,data=df)
# Out:
# <AxesSubplot:xlabel='time', ylabel='tip'>

# %%
sns.barplot(x='sex',y='total_bill',hue='smoker' ,data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex',y='tip',hue='smoker' ,data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill', y='tip' , hue = 'sex', data = df)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.boxplot(x='total_bill' , data=df)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.boxplot(x='tip' , data=df)
# Out:
# <AxesSubplot:xlabel='tip'>

# %%
sns.relplot(x='total_bill', y='tip' , hue = 'sex', col = 'time' ,data = df)

# %%
sns.relplot(x='total_bill', y='tip' , hue = 'sex', col = 'smoker' ,data = df)

# %%
sns.relplot(x='total_bill', y='tip' , hue = 'size', col = 'sex' ,data = df , palette = {1:'red',2:'green',3:'blue',4:'orange',5:'brown',6:'purple'})

# %%
sns.relplot(data=df, x="total_bill", y="tip", hue="day")

# %%
df1 =df[df['sex'] == 'Male']

# %%
sns.displot(x=df.total_bill, data = df, col = df.sex, kde = True)

# %%
sns.displot(x=df.tip, data = df, col = df.sex , kde = True)

# %%
sns.jointplot(x="total_bill",y='tip',data=df , hue = 'sex', kind = 'kde');

# %%
sns.lmplot(x="total_bill",y="tip",data=df , hue="sex")

# %%
sns.catplot(x="day",y="tip",kind='strip',ci=True,data=df );

# %%
sns.catplot(x="day",y="tip",kind='violin',ci=True,data=df , hue = "sex");

# %%
sns.catplot(x="day",y="tip",kind='point',data=df,capsize=0.5);

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.pairplot( df , hue = 'sex')

# %%
sns.lineplot(data=df ,x = 'total_bill', y = 'tip' , hue='sex' )
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(data=df ,x = 'day', y = 'tip' , hue='sex' )
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>
